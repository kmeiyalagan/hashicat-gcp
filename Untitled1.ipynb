# %% [markdown]
# <a href="https://colab.research.google.com/github/kmeiyalagan/hashicat-gcp/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# Series
data = np.array(['P','R','A','T','U','L'])
ser = pd.Series(data)
print(ser)
type(ser)
# Out:
# 0    P
# 1    R
# 2    A
# 3    T
# 4    U
# 5    L
# dtype: object
# pandas.core.series.Series

# %%
data ={'name':['a','b'],'Age':[10,12]}
df=pd.DataFrame(data)
df
# Out:
#   name  Age
# 0    a   10
# 1    b   12

# %%
data ={'name':['a','b'],'Age':[10,12]}
df=pd.DataFrame(data)
df[['Age','name']]
# Out:
#    Age name
# 0   10    a
# 1   12    b

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
data = pd.read_csv('/content/nba.csv')
data
data[['Name']]
# Out:
#               Name
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# ..             ...
# 453   Shelvin Mack
# 454      Raul Neto
# 455   Tibor Pleiss
# 456    Jeff Withey
# 457            NaN
#
# [458 rows x 1 columns]

# %%
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
data.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
data.count
# Out:
# <bound method DataFrame.count of               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# ...

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
PT = pd.pivot_table(data,values='Salary',index=['Team'],columns=['Position'], aggfunc=np.sum)
PT
# Out:
# Position                         C          PF          PG          SF  \
# Team
# Atlanta Hawks           22756250.0  23952268.0   9763400.0   6000000.0
# Boston Celtics           7351395.0  18170960.0  19898606.0   6796117.0
# Brooklyn Nets           20636276.0  14304819.0   8747276.0         NaN
# Charlotte Hornets       20316720.0  14057310.0  14328455.0   6331404.0
# Chicago Bulls           20848760.0  16805037.0  22343064.0   3916320.0
# Cleveland Cavaliers     20486870.0  27882029.0  19654777.0  23917776.0
# Dallas Mavericks         6996057.0  12211340.0  17672733.0  16462102.0
# Denver Nuggets           4851719.0  14049955.0  10447240.0  27982771.0
# Detroit Pistons         12272091.0   8000000.0  17040012.0  20694400.0
# Golden State Warriors   19623748.0  14550625.0  16914511.0  18831837.0
# Houston Rockets         23306640.0   7020455.0   6687086.0  10145957.0
# Indiana Pacers           8000000.0   8259845.0  16218770.0  22873211.0
# ...

# %%
data1 = pd.read_csv('/content/nba.csv')
data1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data1.loc[range(25,30)]
# Out:
#                Name           Team  Number Position   Age Height  Weight  \
# 25      Willie Reed  Brooklyn Nets    33.0       PF  26.0   6-10   220.0
# 26  Thomas Robinson  Brooklyn Nets    41.0       PF  25.0   6-10   237.0
# 27       Henry Sims  Brooklyn Nets    14.0        C  26.0   6-10   248.0
# 28     Donald Sloan  Brooklyn Nets    15.0       PG  28.0    6-3   205.0
# 29   Thaddeus Young  Brooklyn Nets    30.0       PF  27.0    6-8   221.0
#
#          College      Salary
# 25   Saint Louis    947276.0
# 26        Kansas    981348.0
# 27    Georgetown    947276.0
# 28     Texas A&M    947276.0
# 29  Georgia Tech  11235955.0

# %%
data1.iloc[1]
# Out:
# Name           Jae Crowder
# Team        Boston Celtics
# Number                99.0
# Position                SF
# Age                   25.0
# Height                 6-6
# Weight               235.0
# College          Marquette
# Salary           6796117.0
# Name: 1, dtype: object

# %%
data1.iloc[[1,2,4]]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 4                NaN  5000000.0

# %%
data1.iloc[:3]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
data1.iloc[5:]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8     Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9     Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#             College      Salary
# 5               NaN  12000000.0
# ...

# %%
data1.iloc[:,:]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data1.iloc[30:41,[1,2,3]]
# Out:
#                Team  Number Position
# 30  New York Knicks     4.0       SG
# 31  New York Knicks    17.0       PF
# 32  New York Knicks    43.0       SF
# 33  New York Knicks     7.0       SF
# 34  New York Knicks     3.0       PG
# 35  New York Knicks    11.0       SF
# 36  New York Knicks     2.0       SG
# 37  New York Knicks    13.0       PG
# 38  New York Knicks     8.0        C
# 39  New York Knicks     9.0       PF
# 40  New York Knicks     6.0       PF

# %%
data1.iloc[30:41,[1,2,3]]
# Out:
#                Team  Number Position
# 30  New York Knicks     4.0       SG
# 31  New York Knicks    17.0       PF
# 32  New York Knicks    43.0       SF
# 33  New York Knicks     7.0       SF
# 34  New York Knicks     3.0       PG
# 35  New York Knicks    11.0       SF
# 36  New York Knicks     2.0       SG
# 37  New York Knicks    13.0       PG
# 38  New York Knicks     8.0        C
# 39  New York Knicks     9.0       PF
# 40  New York Knicks     6.0       PF

# %%
data2 = data1.iloc[30:41,[1,2,3]]
data2
# Out:
#                Team  Number Position
# 30  New York Knicks     4.0       SG
# 31  New York Knicks    17.0       PF
# 32  New York Knicks    43.0       SF
# 33  New York Knicks     7.0       SF
# 34  New York Knicks     3.0       PG
# 35  New York Knicks    11.0       SF
# 36  New York Knicks     2.0       SG
# 37  New York Knicks    13.0       PG
# 38  New York Knicks     8.0        C
# 39  New York Knicks     9.0       PF
# 40  New York Knicks     6.0       PF

# %%
data2.sort_values('Position')
# Out:
#                Team  Number Position
# 38  New York Knicks     8.0        C
# 31  New York Knicks    17.0       PF
# 39  New York Knicks     9.0       PF
# 40  New York Knicks     6.0       PF
# 34  New York Knicks     3.0       PG
# 37  New York Knicks    13.0       PG
# 32  New York Knicks    43.0       SF
# 33  New York Knicks     7.0       SF
# 35  New York Knicks    11.0       SF
# 30  New York Knicks     4.0       SG
# 36  New York Knicks     2.0       SG

# %%
data2.groupby('Position').get_group('SF')
# Out:
#                Team  Number Position
# 32  New York Knicks    43.0       SF
# 33  New York Knicks     7.0       SF
# 35  New York Knicks    11.0       SF

# %%
data3 = pd.read_csv('/content/nba.csv')
data3
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data4 = data1.iloc[:,[0,1,2,3,8]].groupby('Team').get_group('Boston Celtics')
data4
# Out:
#                Name            Team  Number Position      Salary
# 0     Avery Bradley  Boston Celtics     0.0       PG   7730337.0
# 1       Jae Crowder  Boston Celtics    99.0       SF   6796117.0
# 2      John Holland  Boston Celtics    30.0       SG         NaN
# 3       R.J. Hunter  Boston Celtics    28.0       SG   1148640.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF   5000000.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  12000000.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF   1170960.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C   2165160.0
# 8      Terry Rozier  Boston Celtics    12.0       PG   1824360.0
# 9      Marcus Smart  Boston Celtics    36.0       PG   3431040.0
# 10  Jared Sullinger  Boston Celtics     7.0        C   2569260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG   6912869.0
# 12      Evan Turner  Boston Celtics    11.0       SG   3425510.0
# ...

# %%
data4.groupby('Team').mean()
# Out:
#                    Number        Salary
# Team
# Boston Celtics  31.866667  4.181505e+06

# %%
data3.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
data3 = data3.dropna()

# %%
data3.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64
