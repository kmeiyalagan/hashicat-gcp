# %% [markdown]
# <a href="https://colab.research.google.com/github/kmeiyalagan/hashicat-gcp/blob/master/Pandas_Class_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('file2.csv')

# %%
data
# Out:
#       Unnamed: 0    Dev_Ref
# 0           1043  013.094.G
# 1           1044  013.094.G
# 2           1045  013.094.C
# 3           1046  013.094.C
# 4           1047  013.094.B
# ...          ...        ...
# 4459      248545  097.050.E
# 4460      248546  097.050.F
# 4461      248547  097.050.F
# 4462      248548  097.050.G
# 4463      248549  097.050.G
#
# [4464 rows x 2 columns]

# %%
data.Dev_Ref.unique()
# Out:
# array(['013.094.G', '013.094.C', '013.094.B', '013.094.A', '013.094.F',
#        '013.094.E', '041.050.G', '041.050.C', '041.050.B', '041.050.A',
#        '041.050.F', '041.050.E', '041.138.A', '041.138.B', '041.138.C',
#        '041.138.E', '041.138.F', '041.138.G', '055.116.A', '055.116.B',
#        '055.116.C', '055.116.E', '055.116.F', '055.116.G', '055.149.E',
#        '055.061.E', '055.072.A', '055.072.B', '055.072.C', '055.072.E',
#        '055.072.F', '055.072.G', '069.160.A', '069.160.B', '069.160.C',
#        '069.160.E', '069.160.F', '069.160.G', '069.028.A', '069.028.B',
#        '069.028.C', '069.028.E', '069.028.F', '069.028.G', '069.094.A',
#        '069.094.B', '069.094.C', '069.094.E', '069.094.F', '069.094.G',
#        '111.149.E', '111.061.E', '125.094.A', '125.094.B', '125.094.C',
#        '125.094.E', '125.094.F', '125.094.G', '083.105.E', '083.116.A',
#        '083.116.B', '083.116.C', '083.116.E', '083.116.F', '083.116.G',
# ...

# %%
data['Dev_Ref'].nunique()
# Out:
# 83

# %%
# Groups based on user input
a = input('Please enter the Dev_Ref :',)
b = data.groupby('Dev_Ref').get_group(a)
b.reset_index()
# Out:
# Please enter the Dev_Ref :013.094.G
#     index  Unnamed: 0    Dev_Ref
# 0       0        1043  013.094.G
# 1       1        1044  013.094.G
# 2     196        9251  013.094.G
# 3     197        9252  013.094.G
# 4     382       17612  013.094.G
# 5     383       17613  013.094.G
# 6     568       25973  013.094.G
# 7     569       25974  013.094.G
# 8     744       43795  013.094.G
# 9     745       43796  013.094.G
# 10    940       52003  013.094.G
# 11    941       52004  013.094.G
# 12   1126       60364  013.094.G
# 13   1127       60365  013.094.G
# 14   1312       68725  013.094.G
# 15   1313       68726  013.094.G
# 16   1488       86547  013.094.G
# 17   1489       86548  013.094.G
# 18   1684       94895  013.094.G
# 19   1685       94896  013.094.G
# 20   1870      103256  013.094.G
# 21   1871      103257  013.094.G
# 22   2056      111617  013.094.G
# 23   2057      111618  013.094.G
# 24   2232      129376  013.094.G
# 25   2233      129377  013.094.G
# ...

# %%
# All groups list
for i in data.Dev_Ref.unique():
    print(i)
    print(pd.DataFrame(data.groupby('Dev_Ref').get_group(i)))
    print('\n\n\n\n\n')
# Out:
# 013.094.G
#       Unnamed: 0    Dev_Ref
# 0           1043  013.094.G
# 1           1044  013.094.G
# 196         9251  013.094.G
# 197         9252  013.094.G
# 382        17612  013.094.G
# 383        17613  013.094.G
# 568        25973  013.094.G
# 569        25974  013.094.G
# 744        43795  013.094.G
# 745        43796  013.094.G
# 940        52003  013.094.G
# 941        52004  013.094.G
# 1126       60364  013.094.G
# 1127       60365  013.094.G
# 1312       68725  013.094.G
# 1313       68726  013.094.G
# 1488       86547  013.094.G
# 1489       86548  013.094.G
# 1684       94895  013.094.G
# 1685       94896  013.094.G
# 1870      103256  013.094.G
# 1871      103257  013.094.G
# 2056      111617  013.094.G
# 2057      111618  013.094.G
# 2232      129376  013.094.G
# 2233      129377  013.094.G
# 2428      137560  013.094.G
# 2429      137561  013.094.G
# 2614      145752  013.094.G
# 2615      145753  013.094.G
# 2800      153944  013.094.G
# ...

# %%
data1 = pd.read_csv('nba.csv')

# %%
data2 = data1.iloc[:,0:2]
data2
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
data3 = data1[['Height','Weight']]
data3
# Out:
#     Height  Weight
# 0      6-2   180.0
# 1      6-6   235.0
# 2      6-5   205.0
# 3      6-5   185.0
# 4     6-10   231.0
# ..     ...     ...
# 453    6-3   203.0
# 454    6-1   179.0
# 455    7-3   256.0
# 456    7-0   231.0
# 457    NaN     NaN
#
# [458 rows x 2 columns]

# %%
pd.concat([data2,data3],axis = 1)
# Out:
#               Name            Team Height  Weight
# 0    Avery Bradley  Boston Celtics    6-2   180.0
# 1      Jae Crowder  Boston Celtics    6-6   235.0
# 2     John Holland  Boston Celtics    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics   6-10   231.0
# ..             ...             ...    ...     ...
# 453   Shelvin Mack       Utah Jazz    6-3   203.0
# 454      Raul Neto       Utah Jazz    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    7-3   256.0
# 456    Jeff Withey       Utah Jazz    7-0   231.0
# 457            NaN             NaN    NaN     NaN
#
# [458 rows x 4 columns]

# %%
data1
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df = data1[['Name','Team','Number','Age']]
df
# Out:
#               Name            Team  Number   Age
# 0    Avery Bradley  Boston Celtics     0.0  25.0
# 1      Jae Crowder  Boston Celtics    99.0  25.0
# 2     John Holland  Boston Celtics    30.0  27.0
# 3      R.J. Hunter  Boston Celtics    28.0  22.0
# 4    Jonas Jerebko  Boston Celtics     8.0  29.0
# ..             ...             ...     ...   ...
# 453   Shelvin Mack       Utah Jazz     8.0  26.0
# 454      Raul Neto       Utah Jazz    25.0  24.0
# 455   Tibor Pleiss       Utah Jazz    21.0  26.0
# 456    Jeff Withey       Utah Jazz    24.0  26.0
# 457            NaN             NaN     NaN   NaN
#
# [458 rows x 4 columns]

# %%
df1 = data1[['Name','Position','Salary','Age']]
df1
# Out:
#               Name Position     Salary   Age
# 0    Avery Bradley       PG  7730337.0  25.0
# 1      Jae Crowder       SF  6796117.0  25.0
# 2     John Holland       SG        NaN  27.0
# 3      R.J. Hunter       SG  1148640.0  22.0
# 4    Jonas Jerebko       PF  5000000.0  29.0
# ..             ...      ...        ...   ...
# 453   Shelvin Mack       PG  2433333.0  26.0
# 454      Raul Neto       PG   900000.0  24.0
# 455   Tibor Pleiss        C  2900000.0  26.0
# 456    Jeff Withey        C   947276.0  26.0
# 457            NaN      NaN        NaN   NaN
#
# [458 rows x 4 columns]

# %%
# Concept of Join using the .merge method
res = pd.merge(df,df1,on = ['Name','Age'])
res
# Out:
#               Name            Team  Number   Age Position     Salary
# 0    Avery Bradley  Boston Celtics     0.0  25.0       PG  7730337.0
# 1      Jae Crowder  Boston Celtics    99.0  25.0       SF  6796117.0
# 2     John Holland  Boston Celtics    30.0  27.0       SG        NaN
# 3      R.J. Hunter  Boston Celtics    28.0  22.0       SG  1148640.0
# 4    Jonas Jerebko  Boston Celtics     8.0  29.0       PF  5000000.0
# ..             ...             ...     ...   ...      ...        ...
# 453   Shelvin Mack       Utah Jazz     8.0  26.0       PG  2433333.0
# 454      Raul Neto       Utah Jazz    25.0  24.0       PG   900000.0
# 455   Tibor Pleiss       Utah Jazz    21.0  26.0        C  2900000.0
# 456    Jeff Withey       Utah Jazz    24.0  26.0        C   947276.0
# 457            NaN             NaN     NaN   NaN      NaN        NaN
#
# [458 rows x 6 columns]

# %%
# LEFT
res = pd.merge(df,df1,how = 'left',on = ['Name','Age'])
res
# Out:
#               Name            Team  Number   Age Position     Salary
# 0    Avery Bradley  Boston Celtics     0.0  25.0       PG  7730337.0
# 1      Jae Crowder  Boston Celtics    99.0  25.0       SF  6796117.0
# 2     John Holland  Boston Celtics    30.0  27.0       SG        NaN
# 3      R.J. Hunter  Boston Celtics    28.0  22.0       SG  1148640.0
# 4    Jonas Jerebko  Boston Celtics     8.0  29.0       PF  5000000.0
# ..             ...             ...     ...   ...      ...        ...
# 453   Shelvin Mack       Utah Jazz     8.0  26.0       PG  2433333.0
# 454      Raul Neto       Utah Jazz    25.0  24.0       PG   900000.0
# 455   Tibor Pleiss       Utah Jazz    21.0  26.0        C  2900000.0
# 456    Jeff Withey       Utah Jazz    24.0  26.0        C   947276.0
# 457            NaN             NaN     NaN   NaN      NaN        NaN
#
# [458 rows x 6 columns]

# %%
res = pd.merge(df,df1,how = 'right',on = 'Name')
res
# Out:
#               Name            Team  Number  Age_x Position     Salary  Age_y
# 0    Avery Bradley  Boston Celtics     0.0   25.0       PG  7730337.0   25.0
# 1      Jae Crowder  Boston Celtics    99.0   25.0       SF  6796117.0   25.0
# 2     John Holland  Boston Celtics    30.0   27.0       SG        NaN   27.0
# 3      R.J. Hunter  Boston Celtics    28.0   22.0       SG  1148640.0   22.0
# 4    Jonas Jerebko  Boston Celtics     8.0   29.0       PF  5000000.0   29.0
# ..             ...             ...     ...    ...      ...        ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0   26.0       PG  2433333.0   26.0
# 454      Raul Neto       Utah Jazz    25.0   24.0       PG   900000.0   24.0
# 455   Tibor Pleiss       Utah Jazz    21.0   26.0        C  2900000.0   26.0
# 456    Jeff Withey       Utah Jazz    24.0   26.0        C   947276.0   26.0
# 457            NaN             NaN     NaN    NaN      NaN        NaN    NaN
#
# [458 rows x 7 columns]

# %%
data1 = {'key':['K0','K1','K2','K3'],
         'Key1':['K0','K1','K0','K1'],
         'Name':['Jai','Piyush','Gaurav','Anuj'],
         'Age':[27,24,22,32],}

data2 = {'key':['K0','K1','K2','K3'],
         'Key1':['K0','K0','K0','K0'],
         'Address':['Nagpur','Kanpur','Allahbad','Kannuaj'],
         'Qualification':['Btech','BA','BCom','B.Hons']}

# %%
df = pd.DataFrame(data1)
df1 = pd.DataFrame(data2)

# %%
df
# Out:
#   key Key1    Name  Age
# 0  K0   K0     Jai   27
# 1  K1   K1  Piyush   24
# 2  K2   K0  Gaurav   22
# 3  K3   K1    Anuj   32

# %%
df1
# Out:
#   key Key1   Address Qualification
# 0  K0   K0    Nagpur         Btech
# 1  K1   K0    Kanpur            BA
# 2  K2   K0  Allahbad          BCom
# 3  K3   K0   Kannuaj        B.Hons

# %%
# LEFT
res = pd.merge(df,df1,how = 'left',on = ['key','Key1'])
res
# Out:
#   key Key1    Name  Age   Address Qualification
# 0  K0   K0     Jai   27    Nagpur         Btech
# 1  K1   K1  Piyush   24       NaN           NaN
# 2  K2   K0  Gaurav   22  Allahbad          BCom
# 3  K3   K1    Anuj   32       NaN           NaN

# %%
# RIGHT
res = pd.merge(df,df1,how = 'right',on = ['key','Key1'])
res
# Out:
#   key Key1    Name   Age   Address Qualification
# 0  K0   K0     Jai  27.0    Nagpur         Btech
# 1  K1   K0     NaN   NaN    Kanpur            BA
# 2  K2   K0  Gaurav  22.0  Allahbad          BCom
# 3  K3   K0     NaN   NaN   Kannuaj        B.Hons

# %%
# OUTER
res = pd.merge(df,df1,how = 'outer',on = ['key','Key1'])
res
# Out:
#   key Key1    Name   Age   Address Qualification
# 0  K0   K0     Jai  27.0    Nagpur         Btech
# 1  K1   K1  Piyush  24.0       NaN           NaN
# 2  K2   K0  Gaurav  22.0  Allahbad          BCom
# 3  K3   K1    Anuj  32.0       NaN           NaN
# 4  K1   K0     NaN   NaN    Kanpur            BA
# 5  K3   K0     NaN   NaN   Kannuaj        B.Hons

# %%
# INNER
res = pd.merge(df,df1,how = 'inner',on = ['key','Key1'])
res
# Out:
#   key Key1    Name  Age   Address Qualification
# 0  K0   K0     Jai   27    Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahbad          BCom

# %%
# Date and Time using Pandas
data = pd.date_range('1/1/2022',periods = 24,freq = 'H')
data
# Out:
# DatetimeIndex(['2022-01-01 00:00:00', '2022-01-01 01:00:00',
#                '2022-01-01 02:00:00', '2022-01-01 03:00:00',
#                '2022-01-01 04:00:00', '2022-01-01 05:00:00',
#                '2022-01-01 06:00:00', '2022-01-01 07:00:00',
#                '2022-01-01 08:00:00', '2022-01-01 09:00:00',
#                '2022-01-01 10:00:00', '2022-01-01 11:00:00',
#                '2022-01-01 12:00:00', '2022-01-01 13:00:00',
#                '2022-01-01 14:00:00', '2022-01-01 15:00:00',
#                '2022-01-01 16:00:00', '2022-01-01 17:00:00',
#                '2022-01-01 18:00:00', '2022-01-01 19:00:00',
#                '2022-01-01 20:00:00', '2022-01-01 21:00:00',
#                '2022-01-01 22:00:00', '2022-01-01 23:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
rng = pd.DataFrame()
rng['Date'] = pd.date_range('1/1/2022',periods = 72,freq = 'H')
rng
# Out:
#                   Date
# 0  2022-01-01 00:00:00
# 1  2022-01-01 01:00:00
# 2  2022-01-01 02:00:00
# 3  2022-01-01 03:00:00
# 4  2022-01-01 04:00:00
# ..                 ...
# 67 2022-01-03 19:00:00
# 68 2022-01-03 20:00:00
# 69 2022-01-03 21:00:00
# 70 2022-01-03 22:00:00
# 71 2022-01-03 23:00:00
#
# [72 rows x 1 columns]

# %%
rng['year'] = rng['Date'].dt.year
rng['month'] = rng['Date'].dt.month
rng['day'] = rng['Date'].dt.day
rng['hour'] = rng['Date'].dt.hour
rng['minute'] = rng['Date'].dt.minute
rng.head(10)
# Out:
#                  Date  year  month  day  hour  minute
# 0 2022-01-01 00:00:00  2022      1    1     0       0
# 1 2022-01-01 01:00:00  2022      1    1     1       0
# 2 2022-01-01 02:00:00  2022      1    1     2       0
# 3 2022-01-01 03:00:00  2022      1    1     3       0
# 4 2022-01-01 04:00:00  2022      1    1     4       0
# 5 2022-01-01 05:00:00  2022      1    1     5       0
# 6 2022-01-01 06:00:00  2022      1    1     6       0
# 7 2022-01-01 07:00:00  2022      1    1     7       0
# 8 2022-01-01 08:00:00  2022      1    1     8       0
# 9 2022-01-01 09:00:00  2022      1    1     9       0

# %%
url = 'https://bit.ly/uforeports'

df = pd.read_csv(url)

df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# Convert the Time Column to Datetime Format
df['Time'] = pd.to_datetime(df.Time) #****
df.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
df.Time.dt.hour.head()
df['hour'] = df['Time'].dt.hour
df.groupby('hour').get_group(22)
# Out:
#                 City Colors Reported Shape Reported State                Time  \
# 0             Ithaca             NaN       TRIANGLE    NY 1930-06-01 22:00:00
# 17         Hapeville             NaN            NaN    GA 1942-06-01 22:30:00
# 50          Syracuse             NaN           DISK    NY 1947-02-20 22:15:00
# 83             Raton             NaN           OVAL    NM 1947-07-20 22:00:00
# 84           Modesto            BLUE           DISK    CA 1947-08-08 22:00:00
# ...              ...             ...            ...   ...                 ...
# 18203           Saco             NaN       TRIANGLE    ME 2000-12-27 22:10:00
# 18223     Greenville             NaN            NaN    SC 2000-12-29 22:00:00
# 18226  San Francisco             NaN      FORMATION    CA 2000-12-30 22:00:00
# 18227  San Francisco             NaN       TRIANGLE    CA 2000-12-30 22:00:00
# 18234       Capitola             NaN       TRIANGLE    CA 2000-12-31 22:00:00
#
#        hour
# 0        22
# ...

# %%
data1
# Out:
# {'Age': [27, 24, 22, 32],
#  'Key1': ['K0', 'K1', 'K0', 'K1'],
#  'Name': ['Jai', 'Piyush', 'Gaurav', 'Anuj'],
#  'key': ['K0', 'K1', 'K2', 'K3']}

# %%
data3 = pd.read_csv('nba.csv')

# %%
data3['Name'] = data3['Name'].str.upper()
data3['Team'] = data3['Team'].str.upper()
data3['College'] = data3['College'].str.upper()
data3
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    AVERY BRADLEY  BOSTON CELTICS     0.0       PG  25.0    6-2   180.0
# 1      JAE CROWDER  BOSTON CELTICS    99.0       SF  25.0    6-6   235.0
# 2     JOHN HOLLAND  BOSTON CELTICS    30.0       SG  27.0    6-5   205.0
# 3      R.J. HUNTER  BOSTON CELTICS    28.0       SG  22.0    6-5   185.0
# 4    JONAS JEREBKO  BOSTON CELTICS     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   SHELVIN MACK       UTAH JAZZ     8.0       PG  26.0    6-3   203.0
# 454      RAUL NETO       UTAH JAZZ    25.0       PG  24.0    6-1   179.0
# 455   TIBOR PLEISS       UTAH JAZZ    21.0        C  26.0    7-3   256.0
# 456    JEFF WITHEY       UTAH JAZZ    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                TEXAS  7730337.0
# ...

# %%
data = pd.read_csv('sgdata.xls')
data.head(4)
# Out:
#    Unnamed: 0  wafer_id  erf_num    Wafer_Map_Name     Mask  Extraction_Id  \
# 0        1666     43412     6275  0670-00_standard  0670-00      857842475
# 1        1667     43412     6275  0670-00_standard  0670-00      857842476
# 2        1668     43412     6275  0670-00_standard  0670-00      857842468
# 3        1669     43412     6275  0670-00_standard  0670-00      857842469
#
#    Extraction_Inst_ID  Test_Inst_ID  Tr_Ref            Test_Date Test_Type  \
# 0                7689         12253    6531  2022-03-10 09:16:58  Resistor
# 1                7689         12253    6531  2022-03-10 09:16:58  Resistor
# 2                7689         12253    6531  2022-03-10 09:16:58  Resistor
# 3                7689         12253    6531  2022-03-10 09:16:58  Resistor
#
#     x_test    y_test                           Test_Comments    Dev_Ref  \
# 0 -5500000  86250000  PCM Reliability Session 2_TST004_A37AC  013.094.G
# ...

# %%
data['Comments'].str.split('_',expand = True)
# Out:
#        0    1   2    3
# 0    Dev  RES  24    3
# 1    Dev  RES  24    3
# 2    Dev  RES   2  120
# 3    Dev  RES   2  120
# 4    Dev  RES   2   24
# ..   ...  ...  ..  ...
# 367  Dev  RES   8   12
# 368  Dev  RES  75    3
# 369  Dev  RES  75    3
# 370  Dev  RES  24    3
# 371  Dev  RES  24    3
#
# [372 rows x 4 columns]
